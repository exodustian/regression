# %%
import datetime as dt
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn
seaborn.set_style('darkgrid')

# %%
raw = pd.read_csv('PortfolioRegressionHSCEI.csv')

# %%
df = raw.iloc[1:].set_index('Date')
df.columns = ['pf', 'hsi', 'hscei']
df.index = pd.to_datetime(df.index)

def convert_pct_str_to_float(x):
    return float(x[:-1]) / 100

# df = df.applymap(lambda x: float(x[:-1]) / 100)
df = df.applymap(convert_pct_str_to_float)

df.head()
# Out:
#                 pf     hsi   hscei
# Date
# 2017-01-04 -0.0015 -0.0007 -0.0020
# 2017-01-05  0.0112  0.0146  0.0167
# 2017-01-06 -0.0019  0.0021  0.0013
# 2017-01-09 -0.0012  0.0025 -0.0009
# 2017-01-10  0.0078  0.0083  0.0064

# %%
df.cumsum().plot()

# %% [markdown]
# features = df_clean.columns[-1]
# X = df[features].values.astype(float)
# X = sm.add_constant(X)
